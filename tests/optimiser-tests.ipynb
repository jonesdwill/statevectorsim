# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test_suite import *

# %%
run_verification(n_trials=1000)
# Out:
# Running 1000 verification trials...
# ------------------------------------------------------------
# Trial  | Orig Gates | Opt Gates  | Fidelity   | Status
# ------------------------------------------------------------
# 1      | 36         | 21         | 1.00000000   | PASS
# 2      | 34         | 24         | 1.00000000   | PASS
# 3      | 32         | 28         | 1.00000000   | PASS
# 4      | 38         | 18         | 1.00000000   | PASS
# 5      | 34         | 24         | 1.00000000   | PASS
# 6      | 38         | 26         | 1.00000000   | PASS
# 7      | 34         | 20         | 1.00000000   | PASS
# 8      | 32         | 25         | 1.00000000   | PASS
# 9      | 34         | 18         | 1.00000000   | PASS
# 10     | 34         | 24         | 1.00000000   | PASS
# 11     | 34         | 27         | 1.00000000   | PASS
# 12     | 32         | 16         | 1.00000000   | PASS
# 13     | 32         | 26         | 1.00000000   | PASS
# ...

# %%
compare_optimiser_test()
# Out:
# Depth      | QC Gates   | V0 Gates   | V1 Gates   | V2 Gates
# -------------------------------------------------------
# 10         | 11.4       | 11.4       | 10.0       | 9.1
# 50         | 56.6       | 56.6       | 48.1       | 43.1
# 100        | 116.0      | 116.0      | 96.8       | 85.2
# 200        | 231.8      | 231.8      | 191.1      | 170.2
# 500        | 582.2      | 582.2      | 474.3      | 416.2
