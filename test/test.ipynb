# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from statevectorsim import QuantumState, QuantumCircuit, QuantumGate

# %%
from statevectorsim import QuantumState, QuantumCircuit, QuantumGate

num_qubits = 4

for gate in ['x', 'y', 'z', 'h', 'i', 'cx']:
    qr = QuantumState(num_qubits)
    qc = QuantumCircuit(num_qubits)

    gate_method = getattr(QuantumGate, gate)

    if gate == 'cx':
        print('Gate:', 'x')
        qc.add_gate(QuantumGate.x(0))
        qc.add_gate(gate_method(0, 1))
    else:
        qc.add_gate(gate_method(0))

    qc.run(qr)

    print('Gate:', gate)
    print('Statevector: ', qr.state)
    print('Output: ', qr.measure_all(),'\n')
# Out:
# Gate: x
# Statevector:  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# Output:  [0, 0, 0, 1]
#
# Gate: y
# Statevector:  [0.+0.j 0.+1.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# Output:  [0, 0, 0, 1]
#
# Gate: z
# Statevector:  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# Output:  [0, 0, 0, 0]
#
# Gate: h
# Statevector:  [0.70710678+0.j 0.70710678+0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
# Output:  [0, 0, 0, 1]
#
# Gate: i
# Statevector:  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# Output:  [0, 0, 0, 0]
#
# Gate: x
# Gate: cx
# Statevector:  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
# Output:  [0, 0, 0, 1]
